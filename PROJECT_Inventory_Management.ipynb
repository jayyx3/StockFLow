# %%
import pymysql

# %%
connection= pymysql.connect(host='LOCALHOST',user='root',password='your password')

# %%
cursor=connection.cursor()

# %%
### create database
query="Create database Inventory;"
cursor.execute(query)
connection.commit()

# %%
query1=""" SET FOREIGN_KEY_CHECKS = 0;
drop table if exists category;
          drop table if exists Inventory;
          drop table if exists Product;
          drop table if exists warehouse;
          drop table if exists customer;
          drop table if exists Order_details;"""

for statement in query1.split(";"):
    if statement.strip():
        cursor.execute(statement)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 11
#       9 for statement in query1.split(";"):
#      10     if statement.strip():
# ---> 11         cursor.execute(statement)
#      12 connection.commit()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1046, 'No database selected')

# %%
## create data table 
query= """ use Inventory;

Drop table if exists Category;

Create table Category(
CategoryID varchar(50) Primary key,
CategoryName varchar (50));

Drop table if exists Product;

Create table Product(
ProductID varchar(50) Primary key,
ProductName varchar(50),
CategoryID varchar(50),
Price decimal(10,3),
reorderLEVEL int,
FOREIGN KEY (CategoryID) REFERENCES category(CategoryID));

Drop table if exists warehouse;

drop table if exists warehouse;
create table warehouse(
Warehouseid int Primary key,
WarehouseName varchar(50),
Location varchar(50));


drop table if exists Inventory;

Create table Inventory(
InventoryID int primary key,
ProductID varchar(50),
warehouseid int,
QuantityAvailable int,
FOREIGN KEY (ProductID) REFERENCES Product(ProductID),
FOREIGN KEY (warehouseid) REFERENCES warehouse(warehouseid)
);


drop table if exists customer;

create table customer(
CustomerID varchar(50) Primary key,
CustomerName varchar(50),
Phone varchar(50),
Email varchar(50),
Address varchar(50));

drop table if exists Order_details;

Create table Order_details(
OrderID varchar(50) Primary key,
CustomerID varchar(50),
ProductID varchar(50),
OrderDate date,
QuantityOrdered int,
Price decimal(10,2),
FOREIGN KEY (CustomerID) REFERENCES customer(CustomerID),
FOREIGN KEY (ProductID) REFERENCES Product(ProductID)
);

"""

# %%
for statement in query.split(';'):
    if statement.strip():
        cursor.execute(statement)
        
connection.commit
# Out:
# <bound method Connection.commit of <pymysql.connections.Connection object at 0x000001D8C4C99F70>>

# %%
## insert the data into new created table

# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
engine=create_engine("mysql+pymysql://root:%40Jayjoshi555%40@localhost/Inventory")

# %%
category= pd.read_csv(r"D:\PROJECTS\StockFlow\categories.csv")
product=pd.read_csv(r"D:\PROJECTS\StockFlow\products.csv")
warehouse=pd.read_csv(r"D:\PROJECTS\StockFlow\warehouses.csv")
inventory=pd.read_csv(r"D:\PROJECTS\StockFlow\inventory.csv")
customer=pd.read_csv(r"D:\PROJECTS\StockFlow\customers.csv")
order=pd.read_csv(r"D:\PROJECTS\StockFlow\order_details.csv")

# %%
category.head()
# Out:
#   CategoryID CategoryName
# 0    1Moncid      Monitor
# 1    2Discid         Disk
# 2    3Keycid      Keybord
# 3    4Moucid        Mouse
# 4    5Pricid      Printer

# %%
product.head()
# Out:
#        ProductID          ProductName CategoryID   Price  ReorderLevel
# 0     IN33AlwWEB        Always Webcam   11webcid  673.50            35
# 1     IN34FulMtr         Full Monitor    1Moncid  298.52            48
# 2     IN34OthMtr       Others Monitor    1Moncid  371.04            13
# 3  IN452LeaGraph  Learn Graphics Card    7Gracid  488.19            20
# 4      IN10OnCPU               On CPU   12Cpucid  816.90            10

# %%
warehouse.head()
# Out:
#    WarehouseID               WarehouseName     Location
# 0            1         Davidport Warehouse    Bangalore
# 1            2         Port Paul Warehouse  switzerland
# 2            3           Maryton Warehouse       London
# 3            4         Port Erin Warehouse        Delhi
# 4            5  Lake Sherriville Warehouse     New York

# %%
inventory.head()
# Out:
#    InventoryID      ProductID  WarehouseID  QuantityAvailable
# 0            1     IN33AlwWEB            1                 25
# 1            2     IN34FulMtr            2                121
# 2            3     IN34OthMtr            3                252
# 3            4  IN452LeaGraph            4                454
# 4            5      IN10OnCPU            5                252

# %%
customer.head()
# Out:
#   CustomerID     CustomerName       Phone                      Email  \
# 0      91Aus     Austin Cantu  9791176864  thomasvalerie@collier.biz
# 1      77Tim   Timothy Palmer  9318892926    rmartinez@blackburn.com
# 2      87Sco    Scott Griffin  8982749031        oferguson@gmail.com
# 3      69And    Andrew Butler  9105747541    munozvalerie@vargas.com
# 4      35Jes  Jessica Stanley  9611905793   michellebailey@yahoo.com
#
#        Address
# 0    Bangalore
# 1  switzerland
# 2  switzerland
# 3    Bangalore
# 4  switzerland

# %%
order.head() ## YYYY-MM-DD
# Out:
#   OrderID Customerid      ProductID  ORDERDATE  QuantityOrdered   Price
# 0     OD1      91Aus     IN33AlwWEB   1/4/2024              218  729.42
# 1     OD2      87Sco     IN34OthMtr  3/13/2024                3  823.03
# 2     OD3      66Mar  IN452KeeGraph   6/7/2024               34  908.00
# 3     OD4      54Sus    IN678UnRotr  7/12/2024              379  515.38
# 4     OD5      75Pam   IN453Meedriv   3/2/2024               39  257.60

# %%
order['ORDERDATE']=pd.to_datetime(order['ORDERDATE']).dt.strftime('%Y-%m-%d')

# %%
order.head()
# Out:
#   OrderID Customerid      ProductID   ORDERDATE  QuantityOrdered   Price
# 0     OD1      91Aus     IN33AlwWEB  2024-01-04              218  729.42
# 1     OD2      87Sco     IN34OthMtr  2024-03-13                3  823.03
# 2     OD3      66Mar  IN452KeeGraph  2024-06-07               34  908.00
# 3     OD4      54Sus    IN678UnRotr  2024-07-12              379  515.38
# 4     OD5      75Pam   IN453Meedriv  2024-03-02               39  257.60

# %%
### insert the data into new created table 

category.to_sql('category',con=engine,if_exists='append',index=False)
# Out:
# 16

# %%
product.to_sql('product',con=engine,if_exists='append',index=False)
# Out:
# 96

# %%
warehouse.to_sql('warehouse',con=engine,if_exists='append',index=False)
# Out:
# 100

# %%
inventory.to_sql('Inventory',con=engine,if_exists='append',index=False)
# Out:
# C:\Users\jay\AppData\Local\Temp\ipykernel_11352\1543761948.py:1: UserWarning: The provided table name 'Inventory' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   inventory.to_sql('Inventory',con=engine,if_exists='append',index=False)
# 1000

# %%
customer.to_sql('customer',con=engine,if_exists='append',index=False)
# Out:
# 49

# %%
order.to_sql('order_details',con=engine,if_exists='append',index=False)
# Out:
# 999
